# %%
import pandas as pd
import numpy as np

# %%
# Reading the csv file
df_cars = pd.read_csv("used_cars.csv")
df_cars.head(10)
# Out:
#       brand                            model  model_year       milage  \
# 0      Ford  Utility Police Interceptor Base        2013   51,000 mi.
# 1   Hyundai                     Palisade SEL        2021   34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022   22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015   88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021    9,835 mi.
# 5     Acura                         ILX 2.4L        2016  136,397 mi.
# 6      Audi             S3 2.0T Premium Plus        2017   84,000 mi.
# 7       BMW                           740 iL        2001  242,000 mi.
# 8     Lexus                   RC 350 F Sport        2021   23,436 mi.
# 9     Tesla          Model X Long Range Plus        2020   34,000 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
# 5       Gasoline                                          2.4 Liter
# 6       Gasoline       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 7       Gasoline       282.0HP 4.4L 8 Cylinder Engine Gasoline Fuel
# 8       Gasoline      311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 9            NaN        534.0HP Electric Motor Electric Fuel System
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# 1  8-Speed Automatic         Moonlight Cloud    Gray
# 2          Automatic                    Blue   Black
# 3        7-Speed A/T                   Black   Black
# 4  8-Speed Automatic  Glacier White Metallic   Black
# 5                  F                  Silver  Ebony.
# 6        6-Speed A/T                    Blue   Black
# 7                A/T                   Green   Green
# 8        6-Speed A/T                   Black   Black
# 9                A/T                   Black   Black
#
#                                  accident clean_title    price
# 0  At least 1 accident or damage reported         Yes  $10,300
# 1  At least 1 accident or damage reported         Yes  $38,005
# 2                           None reported         NaN  $54,598
# 3                           None reported         Yes  $15,500
# 4                           None reported         NaN  $34,999
# 5                           None reported         NaN  $14,798
# 6                           None reported         Yes  $31,000
# 7                           None reported         Yes   $7,300
# 8                           None reported         Yes  $41,927
# 9                           None reported         Yes  $69,950

# %%
# Color is not likely to affect resale value unless Very High end model so we drop these columns
df_cars.drop(['ext_col','int_col'],axis=1, inplace=True)
df_cars.shape
# Out:
# (4009, 10)

# %%
print(df_cars.describe)
# Out:
# <bound method NDFrame.describe of          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# 0     E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1          Gasoline                               3.8L V6 24V GDI DOHC
# 2          Gasoline                                     3.5 Liter DOHC
# 3            Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4          Gasoline                         2.0L I4 16V GDI DOHC Turbo
# ...             ...                                                ...
# 4004       Gasoline                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005       Gasoline      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006            NaN                                           Electric
# 4007       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       Gasoline       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission  \
# 0                           6-Speed A/T
# 1                     8-Speed Automatic
# 2                             Automatic
# 3                           7-Speed A/T
# 4                     8-Speed Automatic
# ...                                 ...
# 4004  8-Speed Automatic with Auto-Shift
# 4005     Transmission w/Dual Shift Mode
# 4006                          Automatic
# 4007                                A/T
# 4008                                A/T
#
#                                     accident clean_title     price
# 0     At least 1 accident or damage reported         Yes   $10,300
# 1     At least 1 accident or damage reported         Yes   $38,005
# 2                              None reported         NaN   $54,598
# 3                              None reported         Yes   $15,500
# 4                              None reported         NaN   $34,999
# ...                                      ...         ...       ...
# 4004                           None reported         Yes  $349,950
# 4005                           None reported         Yes   $53,900
# 4006                           None reported         NaN   $90,998
# 4007                           None reported         Yes   $62,999
# 4008  At least 1 accident or damage reported         Yes   $40,000
#
# [4009 rows x 10 columns]>

# %% [markdown]
# #### Cleaning the data

# %%
# missing values
df_cars.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
# filling the missing fuel_type with mode, accident to no and clean_title with yes
df_cars['fuel_type']=df_cars['fuel_type'].fillna(df_cars['fuel_type'].mode()[0])


# We change the whole columns to integer after filling it where 1 represents at least one accident
df_cars['accident']=df_cars['accident'].fillna('None reported')
df_cars['accident']=df_cars['accident'].apply(
    lambda x : 0 if x == "None reported" else 1
    )

df_cars['clean_title']=df_cars['clean_title'].fillna('Yes')
df_cars['clean_title'] = df_cars['clean_title'].apply(lambda x: 1 if x == 'Yes' else 0)



df_cars.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
len(df_cars['engine'].value_counts())
df_cars
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# 0     E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1          Gasoline                               3.8L V6 24V GDI DOHC
# 2          Gasoline                                     3.5 Liter DOHC
# 3            Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4          Gasoline                         2.0L I4 16V GDI DOHC Turbo
# ...             ...                                                ...
# 4004       Gasoline                   6.0L W12 48V PDI DOHC Twin Turbo
# 4005       Gasoline      349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel
# 4006       Gasoline                                           Electric
# 4007       Gasoline      450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 4008       Gasoline       248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                            transmission  accident  clean_title     price
# 0                           6-Speed A/T         1            1   $10,300
# 1                     8-Speed Automatic         1            1   $38,005
# 2                             Automatic         0            1   $54,598
# 3                           7-Speed A/T         0            1   $15,500
# 4                     8-Speed Automatic         0            1   $34,999
# ...                                 ...       ...          ...       ...
# 4004  8-Speed Automatic with Auto-Shift         0            1  $349,950
# 4005     Transmission w/Dual Shift Mode         0            1   $53,900
# 4006                          Automatic         0            1   $90,998
# 4007                                A/T         0            1   $62,999
# 4008                                A/T         1            1   $40,000
#
# [4009 rows x 10 columns]

# %%
# handling the engine columns - we extract the engine size and classify based on that
import re

def extract_engine_size(val):
    match = re.search(r'(\d+(\.\d+)?)\s*[lL]', str(val))
    if match:
        return float(match.group(1))
    return None


df_cars['engine_size'] = df_cars['engine'].apply(extract_engine_size)
df_cars.drop(columns='engine', inplace=True)

# %%
df_cars.isnull().sum()
df_cars = df_cars[df_cars['engine_size'].notnull()]

# %%
df_cars['fuel_type'].value_counts()
df_cars = pd.get_dummies(df_cars, columns=['fuel_type'])

# %%
def simplify_transmission(value):
    val = value.lower()
    if 'cvt' in val:
        return 'CVT'
    elif 'm/t' in val or 'manual' in val:
        return 'Manual'
    elif 'a/t' in val or 'automatic' in val or 'auto-shift' in val:
        return 'Automatic'
    else:
        return 'Automatic'

df_cars.loc[:, 'transmission'] = df_cars['transmission'].apply(simplify_transmission)
df_cars = pd.get_dummies(df_cars, columns=['transmission'])

# since mode is automatic we fill nan with Automatic

# %%
df_cars['milage'].value_counts()
# Out:
# milage
# 110,000 mi.    15
# 45,000 mi.     15
# 55,000 mi.     13
# 120,000 mi.    12
# 92,000 mi.     12
#                ..
# 39,611 mi.      1
# 92,700 mi.      1
# 101,387 mi.     1
# 36,544 mi.      1
# 115,872 mi.     1
# Name: count, Length: 2682, dtype: int64

# %%
df_cars['milage'] = df_cars['milage'].str.replace('mi.', '', regex=False)
df_cars['milage'] = df_cars['milage'].str.replace(',', '')
df_cars['milage'] = df_cars['milage'].str.strip()

df_cars['milage'] = pd.to_numeric(df_cars['milage'], errors='coerce')
df_cars['milage'].describe()
# Out:
# count      3792.000000
# mean      66088.342563
# std       52345.615006
# min         100.000000
# 25%       24211.500000
# 50%       54321.500000
# 75%       95462.500000
# max      405000.000000
# Name: milage, dtype: float64

# %%
df_cars['price'] = df_cars['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12588\117747094.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df_cars['price'] = df_cars['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df_cars
# Out:
#               brand                            model  model_year  milage  \
# 0              Ford  Utility Police Interceptor Base        2013   51000
# 1           Hyundai                     Palisade SEL        2021   34742
# 2             Lexus                    RX 350 RX 350        2022   22372
# 3          INFINITI                 Q50 Hybrid Sport        2015   88900
# 4              Audi        Q3 45 S line Premium Plus        2021    9835
# ...             ...                              ...         ...     ...
# 4003  Mercedes-Benz             E-Class E 300 4MATIC        2018   53705
# 4004        Bentley             Continental GT Speed        2023     714
# 4005           Audi             S4 3.0T Premium Plus        2022   10900
# 4007           Ford                     F-150 Raptor        2020   33000
# 4008            BMW                     X3 xDrive30i        2020   43000
#
#       accident  clean_title     price  engine_size  fuel_type_Diesel  \
# 0            1            1   10300.0          3.7             False
# 1            1            1   38005.0          3.8             False
# 2            0            1   54598.0          3.5             False
# 3            0            1   15500.0          3.5             False
# 4            0            1   34999.0          2.0             False
# ...        ...          ...       ...          ...               ...
# 4003         1            1   25900.0          2.0             False
# 4004         0            1  349950.0          6.0             False
# 4005         0            1   53900.0          3.0             False
# 4007         0            1   62999.0          3.5             False
# 4008         1            1   40000.0          2.0             False
#
#       fuel_type_E85 Flex Fuel  fuel_type_Gasoline  fuel_type_Hybrid  \
# 0                        True               False             False
# 1                       False                True             False
# 2                       False                True             False
# 3                       False               False              True
# 4                       False                True             False
# ...                       ...                 ...               ...
# 4003                    False                True             False
# 4004                    False                True             False
# 4005                    False                True             False
# 4007                    False                True             False
# 4008                    False                True             False
#
#       fuel_type_Plug-In Hybrid  transmission_Automatic  transmission_CVT  \
# 0                        False                    True             False
# 1                        False                    True             False
# 2                        False                    True             False
# 3                        False                    True             False
# 4                        False                    True             False
# ...                        ...                     ...               ...
# 4003                     False                    True             False
# 4004                     False                    True             False
# 4005                     False                    True             False
# 4007                     False                    True             False
# 4008                     False                    True             False
#
#       transmission_Manual
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 4003                False
# 4004                False
# 4005                False
# 4007                False
# 4008                False
#
# [3792 rows x 16 columns]

# %%
df_cars['model'].value_counts()

df_cars = pd.get_dummies(df_cars, columns=['brand'], drop_first=True)

# %%
model_freq = df_cars['model'].value_counts()
threshold = 10
frequent_models = model_freq[model_freq >= threshold].index

df_cars['model'] = df_cars['model'].apply(lambda x: x if x in frequent_models else 'Other')


model_counts = df_cars['model'].value_counts()
df_cars['model_encoded'] = df_cars['model'].map(model_counts)

df_cars['model_encoded'].value_counts()
df_cars.drop(columns='model', inplace=True)

df_cars.reset_index(drop = True, inplace=True)
df_cars.columns
# Out:
# Index(['model_year', 'milage', 'accident', 'clean_title', 'price',
#        'engine_size', 'fuel_type_Diesel', 'fuel_type_E85 Flex Fuel',
#        'fuel_type_Gasoline', 'fuel_type_Hybrid', 'fuel_type_Plug-In Hybrid',
#        'transmission_Automatic', 'transmission_CVT', 'transmission_Manual',
#        'brand_Alfa', 'brand_Aston', 'brand_Audi', 'brand_BMW', 'brand_Bentley',
#        'brand_Bugatti', 'brand_Buick', 'brand_Cadillac', 'brand_Chevrolet',
#        'brand_Chrysler', 'brand_Dodge', 'brand_FIAT', 'brand_Ferrari',
#        'brand_Ford', 'brand_GMC', 'brand_Genesis', 'brand_Honda',
#        'brand_Hummer', 'brand_Hyundai', 'brand_INFINITI', 'brand_Jaguar',
#        'brand_Jeep', 'brand_Karma', 'brand_Kia', 'brand_Lamborghini',
#        'brand_Land', 'brand_Lexus', 'brand_Lincoln', 'brand_Lotus',
#        'brand_MINI', 'brand_Maserati', 'brand_Maybach', 'brand_Mazda',
#        'brand_McLaren', 'brand_Mercedes-Benz', 'brand_Mercury',
#        'brand_Mitsubishi', 'brand_Nissan', 'brand_Plymouth', 'brand_Pontiac',
#        'brand_Porsche', 'brand_RAM', 'brand_Rolls-Royce', 'brand_Saab',
#        'brand_Saturn', 'brand_Scion', 'brand_Subaru', 'brand_Suzuki',
#        'brand_Toyota', 'brand_Volkswagen', 'brand_Volvo', 'brand_smart',
#        'model_encoded'],
#       dtype='object')

# %% [markdown]
# ### Training the model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Trying to spot outliers 
sns.boxplot(y=df_cars['price'])
plt.title('Boxplot for Car Price')
plt.show()

# not clear

# %%
Q1 = df_cars['price'].quantile(0.25)
Q3 = df_cars['price'].quantile(0.75)
IQR = Q3 - Q1

# Outlier thresholds
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Identify outliers
outliers = df_cars[(df_cars['price'] < lower) | (df_cars['price'] > upper)]
print("Outliers detected:", len(outliers))
# Out:
# Outliers detected: 245

# %%
df_cars = df_cars[(df_cars['price'] >= lower) & (df_cars['price'] <= upper)]

# %%
from sklearn.model_selection import train_test_split

x = df_cars.drop(columns='price')
y = df_cars['price']

train, test = train_test_split(df_cars, test_size=0.33, random_state=42)

# %%
train_x = train.drop(columns='price')
train_y = train['price']

# %%
test_x = test.drop(columns='price')
test_y = test['price']

# %%
# we are using linear regression method to train our model
from sklearn.ensemble import RandomForestRegressor

rndm_fr = RandomForestRegressor(n_estimators=100, random_state=7)
rndm_fr.fit(train_x, train_y)
# Out:
# RandomForestRegressor(random_state=7)

# %% [markdown]
# ### Report

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = rndm_fr.predict(test_x)

# 3. Evaluate the model
mae = mean_absolute_error(test_y, y_pred)
mse = mean_squared_error(test_y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(test_y, y_pred)

# 4. Print the scores
print("Random Forest Evaluation:")
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)
# Out:
# Random Forest Evaluation:
# MAE: 6429.719703956732
# MSE: 83704931.83190462
# RMSE: 9149.039940447556
# R² Score: 0.804303409079577

# %% [markdown]
# ## Tuning the model

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [100, 200],             
    'max_depth': [10, 20, None],             
    'min_samples_split': [2, 5],             
    'min_samples_leaf': [1, 2]             
}

# %%
grid_search = GridSearchCV(
    estimator=rndm_fr,
    param_grid=parameters,
    cv=3,
    scoring='r2',
    n_jobs=-1,
    verbose=2
)

# %%
grid_search.fit(train_x, train_y)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=7), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
grid_search.best_score_
# Out:
# np.float64(0.7798536948879944)

# %%
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(test_x)

# %%
print("R² Score:", r2_score(test_y, y_pred))
# Out:
# R² Score: 0.8064958259400844

# %% [markdown]
# ### Exporting the model

# %%
import joblib

joblib.dump(rndm_fr, 'car_price_predictor.pkl')
# Out:
# ['car_price_predictor.pkl']
